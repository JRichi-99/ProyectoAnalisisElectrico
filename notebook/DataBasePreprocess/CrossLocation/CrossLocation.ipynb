# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
periodos_path = Path(r"D:\ProyectoAnalisisElectrico\DiaPromedio\Periodos")

# %%
periodos_disp = [path.name for path in list(periodos_path.iterdir())]
periodos_disp
# Out:
# ['2505_2604']

# %%
periodo = "2505_2604"
periodo_path = periodos_path/periodo
df = pd.read_parquet(periodo_path/(periodo + "_mean_period.parquet"))

# %%
df.reset_index()
# Out:
#           clave   Zona  Hora        medida  CMg[CLP/KWh]  valorizado_CLP  \
# 0        $C$439  Norte     0 -16265.098843     66.273480   -1.068584e+06
# 1        $C$439  Norte     1 -16018.128504     65.684023   -1.044962e+06
# 2        $C$439  Norte     2 -15406.094948     66.415769   -1.018780e+06
# 3        $C$439  Norte     3 -15885.848474     66.879940   -1.053275e+06
# 4        $C$439  Norte     4 -15792.851028     66.719561   -1.045057e+06
# ...         ...    ...   ...           ...           ...             ...
# 164347  licance    Sur    19   -248.411203     80.036791   -2.078386e+04
# 164348  licance    Sur    20   -247.879089     94.317584   -2.398151e+04
# 164349  licance    Sur    21   -249.082963     91.911786   -2.350015e+04
# 164350  licance    Sur    22   -248.555818     90.053520   -2.303938e+04
# 164351  licance    Sur    23   -248.367379     88.514600   -2.251990e+04
#
#        Calendario_Activo           RUT       rut_log  n_ruts  ...  \
# ...
