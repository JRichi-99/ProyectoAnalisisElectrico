# %%
import pandas as pd 
from pathlib import Path

# %%
date = 2511
path=Path(r"D:\ProyectoAnalisisElectrico\MedidasValorizadas")
path = path / f"{date}" / f" {date}_medidas_horarias.parquet"

# %%
df = pd.read_parquet(path)

# %%
df.head()
# Out:
#    Hora     clave nombre_barra  tension                Zona    Razon_Social  \
# 0     0  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 1     1  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 2     2  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 3     3  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 4     4  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
#
#             RUT Nombre_Corto  medida_3_mean  medida_3_min  CMg[CLP/KWh]_mean  \
# 0  94.272.000-9    AES_GENER        -11.550        -12.18          88.859490
# 1  94.272.000-9    AES_GENER        -11.935        -12.46          64.416955
# 2  94.272.000-9    AES_GENER        -11.060        -12.46          51.391525
# 3  94.272.000-9    AES_GENER        -11.270        -12.46          65.100670
# 4  94.272.000-9    AES_GENER         -9.555        -10.36          83.444232
#
#    valorizado_CLP_mean  Fecha_Medicion_last
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999600 entries, 0 to 3999599
# Data columns (total 13 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Hora                 int64
#  1   clave                object
#  2   nombre_barra         object
#  3   tension              int64
#  4   Zona                 object
#  5   Razon_Social         object
#  6   RUT                  object
#  7   Nombre_Corto         object
#  8   medida_3_mean        float64
#  9   medida_3_min         float64
#  10  CMg[CLP/KWh]_mean    float64
#  11  valorizado_CLP_mean  float64
#  12  Fecha_Medicion_last  object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 396.7+ MB
