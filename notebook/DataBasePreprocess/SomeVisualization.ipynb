# %%
import pandas as pd 
from pathlib import Path

# %%
date = 2511
path = Path(r"E:\ProyectoAnalisisElectrico\MedidasValorizadas")
path = path / f"{date}" / f"{date}_medidas_horarias.parquet"

# %%
df = pd.read_parquet(path)

# %%
df.head()
# Out:
#    Hora     clave nombre_barra  tension                Zona    Razon_Social  \
# 0     0  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 1     1  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 2     2  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 3     3  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
# 4     4  36142444   A.HOSPICIO       13  Norte Distribución  AES Andes S.A.
#
#             RUT Nombre_Corto  medida_3_sum  medida_3_min  CMg[CLP/KWh]_mean  \
# 0  94.272.000-9    AES_GENER        -46.20        -12.18          88.859490
# 1  94.272.000-9    AES_GENER        -47.74        -12.46          64.416955
# 2  94.272.000-9    AES_GENER        -44.24        -12.46          51.391525
# 3  94.272.000-9    AES_GENER        -45.08        -12.46          65.100670
# 4  94.272.000-9    AES_GENER        -38.22        -10.36          83.444232
#
#    valorizado_CLP_sum  Fecha_Medicion_last
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3999600 entries, 0 to 3999599
# Data columns (total 13 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Hora                 int64
#  1   clave                str
#  2   nombre_barra         str
#  3   tension              int64
#  4   Zona                 str
#  5   Razon_Social         str
#  6   RUT                  str
#  7   Nombre_Corto         str
#  8   medida_3_sum         float64
#  9   medida_3_min         float64
#  10  CMg[CLP/KWh]_mean    float64
#  11  valorizado_CLP_sum   float64
#  12  Fecha_Medicion_last  str
# dtypes: float64(4), int64(2), str(7)
# memory usage: 777.0 MB
