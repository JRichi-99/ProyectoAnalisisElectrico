# %%
import pandas as pd
from pathlib import Path
import calendar

# %%
db_path = Path(r"E:\ProyectoAnalisisElectrico\DiaPromedio\Mensuales")
to_save_path = Path(r"E:\ProyectoAnalisisElectrico\DiaPromedio\Periodos")

# %%
def days_in_month(date):
    año = date//100
    mes = date%100
    _, dias = calendar.monthrange(2000+año, mes)
    return dias

# %% [markdown]
# Los periodos como tiempos continuos

# %%
[int(date.name) for date in list(db_path.iterdir())]
# Out:
# [2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2601, 2602, 2603, 2604]

# %%
def get_folders(desde, hasta):
    disponibles =  [int(date.name) for date in list(db_path.iterdir())]
    start = disponibles.index(desde)
    stop = disponibles.index(hasta)
    return disponibles[start:stop+1]

get_folders(2508,2601)
# Out:
# [2508, 2509, 2510, 2511, 2512, 2601]
