# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
sii_path = Path(r"D:\ProyectoAnalisisElectrico\SII\ActividadesEconomicasMayo2026\PUB_NOM_ACTECOS.txt")
sii = pd.read_csv(sii_path,sep="\t")

# %%
sii.head()
# Out:
#         RUT DV  CODIGO ACTIVIDAD  \
# 0  45500536  1            292000
# 1  50000066  K            643000
# 2  50000100  3            879000
# 3  50000510  6            492300
# 4  50000710  9            251100
#
#                            DESC. ACTIVIDAD ECONOMICA       FECHA AFECTA A IVA  \
# 0  FABRICACION DE CARROCERIAS PARA VEHICULOS AUTO...  20-04-2025            S
# 1  FONDOS Y SOCIEDADES DE INVERSION Y ENTIDADES F...  01-01-1993            S
# 2     OTRAS ACTIVIDADES DE ATENCION EN INSTITUCIONES  01-01-1993            S
# 3                  TRANSPORTE DE CARGA POR CARRETERA  01-01-1993            S
# 4  FABRICACION DE PRODUCTOS METALICOS PARA USO ES...  01-01-1993            S
#
#    CATEGORIA TRIBUTARIA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
