# %%
import pandas as pd
from pathlib import Path
from src.data_process.k_means_clasification import cluster_por_macrozona, cluster_por_macrozonaV2

df_path = Path(r"E:\ProyectoAnalisisElectrico\PotencialesClientes\PerfilesMercado.parquet")

# %%
df = pd.read_parquet(df_path)

# %%
print("Calculando proporciones diarias...")

df["medida_porcentual"] = df["medida_mean"] / df["medida_total"].replace(0, 1.0)

print("Iniciando segmentación DTW por macrozonas...\n")

df_centros, df_etiquetado = cluster_por_macrozonaV2(
    df=df,
    value_col="medida_porcentual",  
    window=3,                       
    normalize=False,               
    k_max_global=10               
)
# Out:
# Calculando proporciones diarias...
# Iniciando segmentación DTW por macrozonas...
#
#
# Macrozona: Norte Grande
#  └─ Prospectos únicos (Clave+RUT+Región): 122
#  └─ Total de registros horarios: 2,928
# Buscando codo DTW en rango 2-10...
# ✅ Codo DTW detectado en K=5
#
# Macrozona: Centro
#  └─ Prospectos únicos (Clave+RUT+Región): 351
#  └─ Total de registros horarios: 8,424
# Buscando codo DTW en rango 2-10...
# ✅ Codo DTW detectado en K=6
#
# Macrozona: Centro Sur
#  └─ Prospectos únicos (Clave+RUT+Región): 140
#  └─ Total de registros horarios: 3,360
# Buscando codo DTW en rango 2-10...
# ✅ Codo DTW detectado en K=5
#
# Macrozona: Sur
#  └─ Prospectos únicos (Clave+RUT+Región): 125
#  └─ Total de registros horarios: 3,000
# Buscando codo DTW en rango 2-10...
# ✅ Codo DTW detectado en K=6
#
# Macrozona: Norte Chico
#  └─ Prospectos únicos (Clave+RUT+Región): 54
#  └─ Total de registros horarios: 1,296
# Buscando codo DTW en rango 2-10...
# ✅ Codo DTW detectado en K=9
#
# PROCESO COMPLETADO EXITOSAMENTE CON DTW

# %%
# 1. Definir la carpeta de destino
carpeta_salida = Path(r"E:\ProyectoAnalisisElectrico\PotencialesClientes")

# 2. Definir los nuevos nombres de los archivos con el sufijo _porcentual
ruta_centros_porcentual = carpeta_salida / "2505_2604_centroids_porcentual.parquet"
ruta_etiquetado_porcentual = carpeta_salida / "2505_2604_clustered_porcentual.parquet"

# 3. Guardar en formato Parquet
print("Guardando archivos en formato porcentual...")
df_centros.to_parquet(ruta_centros_porcentual, engine="pyarrow", compression="snappy")
df_etiquetado.to_parquet(ruta_etiquetado_porcentual, engine="pyarrow", compression="snappy")

print("--- EXPORTACIÓN EXITOSA ---")
print(f"Centros porcentuales guardados en:\n   {ruta_centros_porcentual}")
print(f"Datos etiquetados porcentuales guardados en:\n   {ruta_etiquetado_porcentual}")
# Out:
# Guardando archivos en formato porcentual...
# --- EXPORTACIÓN EXITOSA ---
# Centros porcentuales guardados en:
#    E:\ProyectoAnalisisElectrico\PotencialesClientes\2505_2604_centroids_porcentual.parquet
# Datos etiquetados porcentuales guardados en:
#    E:\ProyectoAnalisisElectrico\PotencialesClientes\2505_2604_clustered_porcentual.parquet

# %%
df_etiquetado.columns
# Out:
# Index(['clave', 'RUT_CLIENTE', 'REGION_CLIENTE', 'macrozona', 'Zona', 'Hora',
#        'medida_count', 'CLIENTE', 'CLIENTE_log', 'n_clientes', 'TIPO',
#        'NOMBRE_ESTABLECIMIENTO', 'SECTOR', 'SUBSECTOR', 'RUBRO',
#        'DEMANDA_CALOR_MWH_sum', 'DEMANDA_CALOR_MWH_mean',
#        'DEMANDA_CALOR_MWH_std', 'DEMANDA_CALOR_MWH_max',
#        'DEMANDA_CALOR_MWH_min', 'RUT_PROVEEDOR', 'RUT_PROVEEDOR_log',
#        'n_rut_proveedores', 'PROVEEDOR', 'PROVEEDOR_log', 'n_proveedores',
#        'nombre_barra', 'nombre_barra_log', 'n_nombres_barra', 'tension',
#        'tension_log', 'n_tensiones', 'Nombre_Corto', 'Nombre_Corto_log',
#        'n_nombres_cortos', 'periodo_last', 'periodos_log', 'meses_operados',
#        'medida_mean', 'medida_std', 'CMg[CLP/KWh]_mean', 'CMg[CLP/KWh]_std',
#        'CMg[CLP/KWh]_count', 'valorizado_CLP_mean', 'valorizado_CLP_std',
#        'valorizado_CLP_count', 'medida_total', 'medida_porcentual',
#        'clave_unica', 'id_cluster', 'metodo_cluster', 'dtw_window',
#        'dtw_normalize'],
#       dtype='str')
